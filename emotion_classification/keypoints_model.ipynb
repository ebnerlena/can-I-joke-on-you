# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.src.engine.data_adapter import train_validation_split
from tensorflow.keras import layers, models

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import display, Image

import os
import os.path
import mediapipe as mp
import cv2

# %%
# %matplotlib notebook

# %% [markdown]
# # Look At Your Data

# %%
df = pd.read_csv("D:\Documents\GitHub\CIR\emotion_classification\data\smile_dataset\\non_smile_data\Aaron_Eckhart_0001.jpg.csv",
                 sep=';', usecols=[2,3,4])

df.head()
# Out:
#           x         y         z
# 0  0.478620  0.758943 -0.086969
# 1  0.498476  0.606925 -0.233838
# 2  0.492076  0.637054 -0.107097
# 3  0.476964  0.423226 -0.200634
# 4  0.504355  0.560891 -0.256577

# %%
# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['x'], df['y'], df['z'])

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# <div id='61deae0e-c8a9-46bb-a73f-827ba59d19b9'></div>
# Text(0.5, 0, 'Z')

# %%
display(Image(filename="D:\Documents\GitHub\CIR\emotion_classification\data\smile_dataset\\non_smile\Aaron_Eckhart_0001.jpg"))

# %%
df.loc[0]
# Out:
# x    0.478620
# y    0.758943
# z   -0.086969
# Name: 0, dtype: float64

# %%
features = df.values
print(features)
# Out:
# [[ 0.4786202   0.7589426  -0.08696892]
#  [ 0.49847609  0.60692495 -0.23383807]
#  [ 0.4920764   0.63705415 -0.10709658]
#  ...
#  [ 0.60039616  0.2880252  -0.06108231]
#  [ 0.85645998  0.24141848  0.02580323]
#  [ 0.87857103  0.23326856  0.02423774]]

# %% [markdown]
# # Load Data from csv's

# %%
path = "D:\Documents\GitHub\CIR\emotion_classification\data\smile_dataset"

AMOUNT_OF_FEATURES = 468
AMOUNT_OF_FILES = 0

df_non_smile = pd.DataFrame(dtype=float)
df_smile = pd.DataFrame(dtype=float)
df = pd.DataFrame(dtype=float)

classes = ["non_smile_data", "smile_data"]
for c in classes:
    for dirpath, dirnames, filenames in os.walk(f"D:\Documents\GitHub\CIR\emotion_classification\data\smile_dataset\\{c}"):
         for filename in filenames:
            file_path = dirpath + "\\" + filename
            df_new = pd.read_csv(file_path, sep=";", usecols=[0,2,3,4])
            df = pd.concat([df, df_new])
            if c == "non_smile_data":
                df_non_smile = pd.concat([df_non_smile, df_new])
            elif c == "smile_data":
                df_smile = pd.concat([df_smile, df_new])
            AMOUNT_OF_FILES += 1
print(df)
print((AMOUNT_OF_FEATURES, AMOUNT_OF_FILES))
# Out:
#          Class         x         y         z
# 0    non_smile  0.478620  0.758943 -0.086969
# 1    non_smile  0.498476  0.606925 -0.233838
# 2    non_smile  0.492076  0.637054 -0.107097
# 3    non_smile  0.476964  0.423226 -0.200634
# 4    non_smile  0.504355  0.560891 -0.256577
# ..         ...       ...       ...       ...
# 463      smile  0.605286  0.257621 -0.051687
# 464      smile  0.588326  0.277888 -0.076196
# 465      smile  0.582146  0.297006 -0.104985
# 466      smile  0.804237  0.192636 -0.014957
# 467      smile  0.823666  0.177468 -0.015094
#
# [438048 rows x 4 columns]
# (468, 936)

# %%
print(df.values)
# Out:
# [['non_smile' 0.4786202013492584 0.7589426040649414 -0.0869689211249351]
#  ['non_smile' 0.4984760880470276 0.6069249510765076 -0.2338380664587021]
#  ['non_smile' 0.4920763969421386 0.6370541453361511 -0.1070965826511383]
#  ...
#  ['smile' 0.5821459889411926 0.2970063090324402 -0.1049851328134536]
#  ['smile' 0.804236650466919 0.192635953426361 -0.0149569129571318]
#  ['smile' 0.8236660957336426 0.1774682402610778 -0.0150936227291822]]

# %%
print(df.iloc[0])
print(df.iloc[467])
# Out:
# Class    non_smile
# x          0.47862
# y         0.758943
# z        -0.086969
# Name: 0, dtype: object
# Class    non_smile
# x         0.878571
# y         0.233269
# z         0.024238
# Name: 467, dtype: object

# %%
X = df[['x', 'y', 'z']].values
Y = df['Class'].values

X = X.reshape(int(np.size(X) / (AMOUNT_OF_FEATURES * 3)), AMOUNT_OF_FEATURES, 3)
print(np.shape(X))

Y = Y[np.arange(0, np.size(Y), AMOUNT_OF_FEATURES)]
Y = np.where(Y == "non_smile", 0, 1)
print(np.shape(Y))
# Out:
# (936, 468, 3)
# (936,)

# %% [markdown]
# # Construct model

# %%
model = models.Sequential()
model.add(layers.Conv1D(16, 3, activation='relu', input_shape=(AMOUNT_OF_FEATURES, 3)))
model.add(layers.MaxPooling1D(2))
model.add(layers.Conv1D(32, 3, activation='relu'))
model.add(layers.MaxPooling1D(2))
model.add(layers.Conv1D(64, 3, activation='relu'))
model.add(layers.MaxPooling1D(2))
model.add(layers.Conv1D(64, 3, activation='relu'))
model.add(layers.MaxPooling1D(2))
model.add(layers.Conv1D(64, 3, activation='relu'))
model.add(layers.Dropout(rate=0.2))
model.add(layers.MaxPooling1D(2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(2))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 466, 16)           160
#
#  max_pooling1d_8 (MaxPoolin  (None, 233, 16)           0
#  g1D)
#
#  conv1d_9 (Conv1D)           (None, 231, 32)           1568
#
#  max_pooling1d_9 (MaxPoolin  (None, 115, 32)           0
#  g1D)
#
#  conv1d_10 (Conv1D)          (None, 113, 64)           6208
#
#  max_pooling1d_10 (MaxPooli  (None, 56, 64)            0
#  ng1D)
#
#  conv1d_11 (Conv1D)          (None, 54, 64)            12352
#
#  max_pooling1d_11 (MaxPooli  (None, 27, 64)            0
#  ng1D)
#
#  conv1d_12 (Conv1D)          (None, 25, 64)            12352
#
#  dropout (Dropout)           (None, 25, 64)            0
#
#  max_pooling1d_12 (MaxPooli  (None, 12, 64)            0
#  ng1D)
#
#  flatten_2 (Flatten)         (None, 768)               0
#
#  dense_4 (Dense)             (None, 64)                49216
#
#  dense_5 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 81986 (320.26 KB)
# Trainable params: 81986 (320.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Training loop
history = model.fit(X, Y, epochs=500, validation_split=0.2)

# Print history (optional)
# print(history.history)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 4s 48ms/step - loss: 0.6537 - accuracy: 0.6444 - val_loss: 1.3106 - val_accuracy: 0.0000e+00
# Epoch 2/500
# 24/24 [==============================] - 1s 25ms/step - loss: 0.6553 - accuracy: 0.6457 - val_loss: 0.9654 - val_accuracy: 0.0000e+00
# Epoch 3/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.6462 - accuracy: 0.6457 - val_loss: 1.0279 - val_accuracy: 0.0000e+00
# Epoch 4/500
# 24/24 [==============================] - 1s 23ms/step - loss: 0.6445 - accuracy: 0.6457 - val_loss: 0.9606 - val_accuracy: 0.0000e+00
# Epoch 5/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.6354 - accuracy: 0.6457 - val_loss: 0.8823 - val_accuracy: 0.0000e+00
# Epoch 6/500
# 24/24 [==============================] - 1s 23ms/step - loss: 0.6169 - accuracy: 0.6457 - val_loss: 0.8623 - val_accuracy: 0.1064
# Epoch 7/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.5610 - accuracy: 0.7072 - val_loss: 0.4703 - val_accuracy: 0.8883
# Epoch 8/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.4898 - accuracy: 0.7727 - val_loss: 0.5533 - val_accuracy: 0.7500
# Epoch 9/500
# 24/24 [==============================] - 1s 23ms/step - loss: 0.3740 - accuracy: 0.8382 - val_loss: 0.5660 - val_accuracy: 0.7394
# Epoch 10/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.2764 - accuracy: 0.8890 - val_loss: 0.3158 - val_accuracy: 0.8564
# Epoch 11/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.2450 - accuracy: 0.9011 - val_loss: 0.2230 - val_accuracy: 0.8989
# Epoch 12/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.2201 - accuracy: 0.9104 - val_loss: 0.4513 - val_accuracy: 0.8032
# Epoch 13/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.2204 - accuracy: 0.9078 - val_loss: 0.1990 - val_accuracy: 0.9202
# Epoch 14/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1994 - accuracy: 0.9238 - val_loss: 0.1427 - val_accuracy: 0.9628
# Epoch 15/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1842 - accuracy: 0.9291 - val_loss: 0.2713 - val_accuracy: 0.8723
# Epoch 16/500
# 24/24 [==============================] - 1s 23ms/step - loss: 0.1769 - accuracy: 0.9345 - val_loss: 0.1478 - val_accuracy: 0.9521
# Epoch 17/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1756 - accuracy: 0.9412 - val_loss: 0.1655 - val_accuracy: 0.9309
# Epoch 18/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1638 - accuracy: 0.9385 - val_loss: 0.5436 - val_accuracy: 0.7500
# Epoch 446/500
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0830 - accuracy: 0.9639 - val_loss: 0.1782 - val_accuracy: 0.9681
# Epoch 447/500
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0459 - accuracy: 0.9840 - val_loss: 0.3639 - val_accuracy: 0.9309
# Epoch 448/500
# 24/24 [==============================] - 1s 35ms/step - loss: 0.0340 - accuracy: 0.9866 - val_loss: 0.2408 - val_accuracy: 0.9628
# Epoch 449/500
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0324 - accuracy: 0.9906 - val_loss: 0.3815 - val_accuracy: 0.9255
# Epoch 450/500
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0123 - accuracy: 0.9947 - val_loss: 0.2787 - val_accuracy: 0.9681
# Epoch 451/500
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0077 - accuracy: 0.9960 - val_loss: 0.2940 - val_accuracy: 0.9681
# Epoch 452/500
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0282 - accuracy: 0.9905
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Training loop
# ----> 2 history = model.fit(X, Y, epochs=500, validation_split=0.2)
#
# File ~\miniconda3\envs\CIR\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\miniconda3\envs\CIR\lib\site-packages\keras\src\engine\training.py:1832, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1816 if getattr(self, "_eval_data_handler", None) is None:
#    1817     self._eval_data_handler = data_adapter.get_data_handler(
#    1818         x=val_x,
#    1819         y=val_y,
#    (...)
#    1830         pss_evaluation_shards=self._pss_evaluation_shards,
#    1831     )
# -> 1832 val_logs = self.evaluate(
#    1833     x=val_x,
#    1834     y=val_y,
#    1835     sample_weight=val_sample_weight,
#    1836     batch_size=validation_batch_size or batch_size,
#    1837     steps=validation_steps,
#    1838     callbacks=callbacks,
#    1839     max_queue_size=max_queue_size,
#    1840     workers=workers,
#    1841     use_multiprocessing=use_multiprocessing,
#    1842     return_dict=True,
#    1843     _use_cached_eval_dataset=True,
#    1844 )
#    1845 val_logs = {
#    1846     "val_" + name: val for name, val in val_logs.items()
#    1847 }
#    1848 epoch_logs.update(val_logs)
#
# File ~\miniconda3\envs\CIR\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\miniconda3\envs\CIR\lib\site-packages\keras\src\engine\training.py:2261, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2259 if self.enable_tune_steps_per_execution:
#    2260     self._steps_per_execution_tuner.start()
# -> 2261 for (
#    2262     _,
#    2263     dataset_or_iterator,
#    2264 ) in data_handler.enumerate_epochs():  # Single epoch.
#    2265     self.reset_metrics()
#    2266     with data_handler.catch_stop_iteration():
#
# File ~\miniconda3\envs\CIR\lib\site-packages\keras\src\engine\data_adapter.py:1341, in DataHandler.enumerate_epochs(self)
#    1339 """Yields `(epoch, tf.data.Iterator)`."""
#    1340 with self._truncate_execution_to_epoch():
# -> 1341     data_iterator = iter(self._dataset)
#    1342     for epoch in range(self._initial_epoch, self._epochs):
#    1343         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File ~\miniconda3\envs\CIR\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:496, in DatasetV2.__iter__(self)
#     494 if context.executing_eagerly() or ops.inside_function():
#     495   with ops.colocate_with(self._variant_tensor):
# --> 496     return iterator_ops.OwnedIterator(self)
#     497 else:
#     498   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     499                      "iteration in eager mode or within tf.function.")
#
# File ~\miniconda3\envs\CIR\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:705, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     701   if (components is not None or element_spec is not None):
#     702     raise ValueError(
#     703         "When `dataset` is provided, `element_spec` and `components` must "
#     704         "not be specified.")
# --> 705   self._create_iterator(dataset)
#     707 self._get_next_call_count = 0
#
# File ~\miniconda3\envs\CIR\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:744, in OwnedIterator._create_iterator(self, dataset)
#     741   assert len(fulltype.args[0].args[0].args) == len(
#     742       self._flat_output_types)
#     743   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 744 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~\miniconda3\envs\CIR\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3451, in make_iterator(dataset, iterator, name)
#    3449 if tld.is_eager:
#    3450   try:
# -> 3451     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3452       _ctx, "MakeIterator", name, dataset, iterator)
#    3453     return _result
#    3454   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure()
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
model2 = models.Sequential()
model2.add(layers.Conv1D(16, 3, activation='relu', input_shape=(AMOUNT_OF_FEATURES, 3)))
model2.add(layers.MaxPooling1D(2))
model2.add(layers.Conv1D(32, 3, activation='relu'))
model2.add(layers.MaxPooling1D(2))
model2.add(layers.Conv1D(64, 3, activation='relu'))
model2.add(layers.MaxPooling1D(2))
model2.add(layers.Conv1D(128, 3, activation='relu'))
model2.add(layers.MaxPooling1D(2))
model2.add(layers.Flatten())
model2.add(layers.Dense(64, activation='relu'))
model2.add(layers.Dense(2))
model2.summary()

# %%
model2.summary()

# %%
model2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
X_no_z = df[['x', 'y']].values

X_no_z = X_no_z.reshape(int(np.size(X_no_z) / (AMOUNT_OF_FEATURES * 2)), AMOUNT_OF_FEATURES, 2)
print(np.shape(X_no_z))

# %%
# Training loop
history2 = model2.fit(X, Y, epochs=100, validation_split=0.2)

# Print history (optional)
# print(history2.history)

# %%
acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']
loss = history2.history['loss']
val_loss = history2.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure()
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
for dirpath, dirnames, filenames in os.walk(f"D:\Documents\GitHub\CIR\emotion_classification\data\smile_dataset\\test_data"):
    for filename in filenames[:100]:
        csv_path = dirpath + "/" + filename
        jpg_path = dirpath[:-5] + "/" + filename[:-4]
        display(Image(filename=jpg_path))
        df_pic = pd.read_csv(csv_path, sep=";", usecols=[0,2,3,4])
        X = df_pic[['x', 'y', 'z']].values
        X = X.reshape(int(np.size(X) / (AMOUNT_OF_FEATURES * 3)), AMOUNT_OF_FEATURES, 3)
        predictions = model.predict(X)
        c = np.argmax(predictions, axis=1)
        print(classes[c[0]][:-5])

# %%
mp_drawing = mp.solutions.drawing_utils
mp_face_mesh = mp.solutions.face_mesh

def extract_face_landmarks(image_path):
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    with mp_face_mesh.FaceMesh(min_detection_confidence=0.5, min_tracking_confidence=0.5) as face_mesh:
        results = face_mesh.process(image_rgb)
        if results.multi_face_landmarks:
          landmarks = results.multi_face_landmarks[0].landmark
        else:
          return None
    return landmarks

# %%
self_test = [
    "D:\Documents\GitHub\CIR\emotion_classification\data\own_data\\neutral.jpg",
     "D:\Documents\GitHub\CIR\emotion_classification\data\own_data\\slightsmile.jpg",
     "D:\Documents\GitHub\CIR\emotion_classification\data\own_data\\smile.jpg",
     "D:\Documents\GitHub\CIR\emotion_classification\data\own_data\\opensmile.jpg",
     "D:\Documents\GitHub\CIR\emotion_classification\data\own_data\\natsmile.jpg",
     # "D:\Documents\GitHub\CIR\emotion_classification\data\own_data\\smile1.jpg",
     # "D:\Documents\GitHub\CIR\emotion_classification\data\own_data\\smile2.jpg",
     # "D:\Documents\GitHub\CIR\emotion_classification\data\own_data\\smile3.jpg",
     # "D:\Documents\GitHub\CIR\emotion_classification\data\own_data\\neutralgloria.jpg"
]

for test in self_test:
    x, y, z = [], [], []
    landmarks = extract_face_landmarks(test)
    display(Image(filename=test))
    for i, landmark in enumerate(landmarks):
        x.append(landmark.x)
        y.append(landmark.y)
        z.append(landmark.z)
    df = pd.DataFrame({"x": x, "y": y, "z": z})
    X = df[['x', 'y', 'z']].values
    X = X.reshape(int(np.size(X) / (AMOUNT_OF_FEATURES * 3)), AMOUNT_OF_FEATURES, 3)
    predictions = model.predict(X)
    c = np.argmax(predictions, axis=1)
    print(classes[c[0]][:-5])
